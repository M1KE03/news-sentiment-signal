# %% [markdown]
# # 04 — Volume and volatility  (Stage 5)
#
# RQ4 — the outcomes where media-sentiment effects have been documented (Tetlock 2007). Exploratory: this family is separate from the primary and secondary return tests and cannot supply a result the primary specification did not.
#
# **The primary test for each outcome is a HAC Wald test of the joint null `b1 = b2 = b3 = 0`** across level, intensity (|S_t|) and dispersion (d_t). Individual coefficients — `d_t`'s included — are read **descriptively afterwards**, with pointwise intervals. That ordering is the point: it is what stops one coefficient being promoted to the headline once someone has looked at it.
#
# `d_t` is the within-day **standard deviation of model-assigned tone**, not investor disagreement (P21): these are headlines about different events, scored by a model, not observations of belief. Its relation to volume is an extension to test, not a replication of Tetlock, which links unusually high or low pessimism — not dispersion — to volume. Bounded scores also tie the mean and dispersion mechanically, so `b2` and `b3` are not independent dimensions. Note the sample reduction from the n_t ≥ 5 requirement on d_t.
#
# > **Corrected 2026-09-10 (R09, P21/P23).** This cell previously called RQ4 "the act most likely to yield a positive result" and instructed the reader to "report the d_t coefficient prominently: disagreement predicting volume is the project's most plausible positive finding." That is the predetermined finding the audit set out to remove, and the joint-null ordering above exists precisely to prevent it.
#
# **Produces:** Table 5, Figure 3.

# %%
import sys; sys.path.insert(0, '..')
import numpy as np, pandas as pd
import config

from src import inference, plots

# panel = pd.read_parquet(config.PANEL_PARQUET)
# sample, _ = inference.analysis_sample(panel)
