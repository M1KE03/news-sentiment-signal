# %% [markdown]
# # 04 — Volume and volatility  (Stage 5)
#
# RQ4 — the outcomes where media-sentiment effects are documented (Tetlock 2007), and the act most likely to yield a positive result.
#
# Report the d_t coefficient prominently: disagreement predicting volume is the project's most plausible positive finding. Note the sample reduction from the n_t ≥ 5 requirement on d_t.
#
# **Produces:** Table 5, Figure 3.

# %%
import sys; sys.path.insert(0, '..')
import numpy as np, pandas as pd
import config

from src import inference, plots

# panel = pd.read_parquet(config.PANEL_PARQUET)
# sample, _ = inference.analysis_sample(panel)
